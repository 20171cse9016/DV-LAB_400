# %% [markdown]
# <a href="https://colab.research.google.com/github/20171cse9016/DV-LAB_400/blob/master/lab_Session_1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#first program for DV 

#importing packages

import numpy as np
import time
print(time.ctime())
# Out:
# Mon Sep  7 10:03:29 2020

# %%
#assigment 1 random numbers
#importing packages

import numpy as np
from matplotlib import pyplot as plt

# %%
# data

y=np.random.randn(100)
x=[x for x in range (len(y))]

# %%
#plotting the graph between  x and  y

plt.plot(x,y)
plt.title("sample plot for the data")
plt.show()

# %%
#assigment 1 sin
#importing packages

import numpy as np
from matplotlib import pyplot as plt

# %%
#data

y=np.sin(x)
x=[x for x in range (100)]

# %%
#plotting the graph between  x and  y

plt.plot(x,y)
plt.title("sample plot for the sin")
plt.show()

# %%
#assigment 1 cosine
#importing packages

import numpy as np
from matplotlib import pyplot as plt

# %%
#data

y=np.cos(x)
x=[x for x in range (100)]

# %%
#plotting the graph between  x and  y

plt.plot(x,y)
plt.title("sample plot for the cosine")
plt.show()
